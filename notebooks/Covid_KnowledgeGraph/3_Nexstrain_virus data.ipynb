# %% [markdown]
# # This notebook serves the purpose of loading in the Nextstrain data to link to the information contained in the COVID Knowledge Graph

# %%
import pyforest

# %%
df=pd.read_csv('D:/GitHub/COVID-19/data/NextStrain/metadata.tsv',encoding='utf-8', sep="\t")

# %%
df
# Out:
#                           strain virus  gisaid_epi_isl  ...                     url title date_submitted
# 0        Algeria/G0638_2264/2020  ncov  EPI_ISL_418241  ...  https://www.gisaid.org     ?     2020-03-29
# 1        Algeria/G0640_2265/2020  ncov  EPI_ISL_418242  ...  https://www.gisaid.org     ?     2020-03-29
# 2        Algeria/G0860_2262/2020  ncov  EPI_ISL_420037  ...  https://www.gisaid.org     ?     2020-04-04
# 3               Anhui/SZ005/2020  ncov  EPI_ISL_413485  ...  https://www.gisaid.org     ?     2020-03-05
# 4            Argentina/C121/2020  ncov  EPI_ISL_420600  ...  https://www.gisaid.org     ?     2020-04-06
# ...                          ...   ...             ...  ...                     ...   ...            ...
# 12213  pangolin/Guangxi/P2V/2017  ncov  EPI_ISL_410542  ...  https://www.gisaid.org     ?     2020-02-17
# 12214  pangolin/Guangxi/P3B/2017  ncov  EPI_ISL_410543  ...  https://www.gisaid.org     ?     2020-02-17
# ...

# %%
df.division.unique()
# Out:
# array(['Boufarik', 'Blida', 'Anhui', nan, 'New South Wales',
#        'Northern Territory', 'Northern territory', 'Queensland',
#        'Victoria', 'Western Australia', 'Vienna', 'Beijing', 'Ukkel',
#        'Blegny', 'Belgium', 'Herent', 'Leuven', 'Sint-Niklaas',
#        'Saint-Ghislain', 'Wervik', 'Tubize', 'Colfontaine', 'Beersel',
#        'Kaulile', 'Lubbeek', 'Waterloo', 'Beringen', 'Herselt',
#        'Kraainem', 'Andenne', 'Waasmunster', 'Tournai', 'Boussu', 'Mons',
#        'Liège', 'Zinnik', 'Eupen', 'Mouscron', 'Courcelles', 'Quevy',
#        'Oostrozebeke', 'Couthuin', 'Kessel-Lo', 'Elsene', 'Charleroi',
#        'Sint-Gillis-Waas', 'Estinnes', 'Dilbeek', 'Dendermonde', 'Ravels',
#        'Linter', 'Grimbergen', 'Fontaine-l Eveque', 'Wanze',
#        'Walloon Brabant', 'Geraardsbergen', 'Asse', 'Genappe', 'Namur',
#        'Lasne', 'Rixensart', 'Riemst', 'Flanders', 'Montigny-le-Tilleul',
#        'Zolder', 'Houthalen-Helchteren', 'Holsbeek', 'Berloz', 'Chaineux',
# ...
